# %%
# Install the Google Cloud Storage client library and the gcsfs filesystem interface for Python. The --quiet flag suppresses output during installation.
# !pip install google-cloud-storage gcsfs --quiet

# %%
# Authentication with google cloud
from google.colab import auth
auth.authenticate_user()
# Out:
# WARNING: google.colab.auth.authenticate_user() is not supported in Colab Enterprise.

# %%
from google.cloud import storage

# GCS bucket and file details
BUCKET_NAME = "exercise-recognition-dataset"
ZIP_FILE_PATH = "exercise_dataset.zip"
LOCAL_ZIP_PATH = "/content/exercise_dataset.zip"

# Initialize GCS client
client = storage.Client()

# Get bucket reference
bucket = client.bucket(BUCKET_NAME)

# Get blob reference
blob = bucket.blob(ZIP_FILE_PATH)

# Download blob to local file
blob.download_to_filename(LOCAL_ZIP_PATH)

print("Downloaded successfully.")
# Out:
# Downloaded successfully.

# %%
# Unzipping the files
import zipfile

# Open the downloaded zip file in read mode ('r')
with zipfile.ZipFile(LOCAL_ZIP_PATH, 'r') as zip_ref:
    # Extract all the contents of the zip file to the specified directory
    zip_ref.extractall("/content/exercise_dataset")

# Print a confirmation message when the extraction is finished
print("Extraction complete.")
# Out:
# Extraction complete.

# %%
# Installing required libraries and dependencies
# !pip install tensorflow opencv-python mediapipe scikit-learn matplotlib
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Collecting mediapipe
#   Downloading mediapipe-0.10.21-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.6.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.69.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe) (24.3.0)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.4.33)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe) (4.10.0.84)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.5.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Downloading mediapipe-0.10.21-cp310-cp310-manylinux_2_28_x86_64.whl (35.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 52.2 MB/s eta 0:00:00
# Downloading sounddevice-0.5.2-py3-none-any.whl (32 kB)
# Installing collected packages: sounddevice, mediapipe
# Successfully installed mediapipe-0.10.21 sounddevice-0.5.2

# %%
import os
import cv2

# Define input and output directories
INPUT_DIR = '/content/exercise_dataset/Exercises'
OUTPUT_DIR = '/content/frames_dataset'
FRAME_RATE = 1  # Desired frames per second

# Create the output directory if it doesn't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Function to extract frames from a video
def extract_frames(video_path, save_path, frame_rate=1):
    cap = cv2.VideoCapture(video_path)  # Open the video file
    fps = cap.get(cv2.CAP_PROP_FPS)      # Get original video FPS
    frame_interval = int(fps // frame_rate)  # Calculate frame interval for desired rate

    frame_id = 0
    saved_frame = 0

    while cap.isOpened():
        ret, frame = cap.read()  # Read the next frame
        if not ret:
            break  # End of video
        if frame_id % frame_interval == 0:
            frame_file = os.path.join(save_path, f'frame_{saved_frame:05d}.jpg')
            cv2.imwrite(frame_file, frame)  # Save the frame as JPG
            saved_frame += 1
        frame_id += 1

    cap.release()  # Release video object


# Loop through class folders and video files
for label in os.listdir(INPUT_DIR):
    class_path = os.path.join(INPUT_DIR, label)
    if os.path.isdir(class_path):
        for video in os.listdir(class_path):
            if video.endswith(('.mp4', '.avi', '.mov', '.mkv')):
                video_path = os.path.join(class_path, video)
                video_name = os.path.splitext(video)[0]
                save_dir = os.path.join(OUTPUT_DIR, label, video_name)
                os.makedirs(save_dir, exist_ok=True)
                extract_frames(video_path, save_dir, FRAME_RATE)

print("Frame extraction complete!")
# Out:
# Frame extraction complete!

# %%
"""Because the target classes `Kettlebell_swings` and `RDL_dumbbell` have subfolders within them rather than recomputing
the frame by merging the subfolder, we will rather focus on those target classes only. We are ignoring the weight
parameter it maybe important from future aspects point of view during the data collection."""

import os

# Define target classes to process.  The script will only process videos within these class directories.
TARGET_CLASSES = ['Kettlebell_swings', 'RDL_dumbbell']

# Walk only inside the target class folders
for target in TARGET_CLASSES:
    class_path = os.path.join(INPUT_DIR, target)  # Path to the current target class directory.
    output_class_dir = os.path.join(OUTPUT_DIR, target) # Path to the output directory for the current class.
    os.makedirs(output_class_dir, exist_ok=True)    # Create the output directory if it doesn't exist.

    for root, _, files in os.walk(class_path): # Walk through the directory tree rooted at class_path.
        for file in files:
            if file.endswith(('.mp4', '.avi', '.mov', '.mkv')): # Check if the file is a video file.
                video_path = os.path.join(root, file)         # Full path to the video file.
                video_name = os.path.splitext(file)[0]     # Video filename without extension.
                save_dir = os.path.join(output_class_dir, video_name) # Directory to save frames for this video.
                os.makedirs(save_dir, exist_ok=True)        # Create the frame save directory.
                extract_frames(video_path, save_dir, FRAME_RATE) # Extract frames from the video.

print("Subfolders merged and frame extraction complete.")
# Out:
# Subfolders merged and frame extraction complete.

# %%
import mediapipe as mp
import pandas as pd
import os
import cv2

# Directories
FRAME_DIR = '/content/frames_dataset'
CSV_OUTPUT_DIR = '/content/pose_csv_dataset'

# Initialize Mediapipe Pose
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True)

def extract_pose_from_frame(img_path):
    """Extract pose landmarks from an image."""
    img = cv2.imread(img_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = pose.process(img_rgb)

    if results.pose_landmarks:
        row = []
        for lm in results.pose_landmarks.landmark:
            row.extend([lm.x, lm.y, lm.z, lm.visibility])
        return row
    return None

# Make output directory
os.makedirs(CSV_OUTPUT_DIR, exist_ok=True)

# Process each class folder
for label in os.listdir(FRAME_DIR):
    class_path = os.path.join(FRAME_DIR, label)
    if os.path.isdir(class_path):
        for video in os.listdir(class_path):
            video_path = os.path.join(class_path, video)
            if os.path.isdir(video_path):
                pose_data = []
                frame_files = sorted(os.listdir(video_path))
                print(f"Processing {video}...")

                for frame_file in frame_files:
                    frame_path = os.path.join(video_path, frame_file)
                    row = extract_pose_from_frame(frame_path)
                    if row:
                        pose_data.append([frame_file] + row)

                if pose_data:
                    columns = ['frame']
                    for i in range(33):
                        columns.extend([f'x{i}', f'y{i}', f'z{i}', f'v{i}'])

                    df = pd.DataFrame(pose_data, columns=columns)
                    out_dir = os.path.join(CSV_OUTPUT_DIR, label)
                    os.makedirs(out_dir, exist_ok=True)
                    out_csv = os.path.join(out_dir, f"{video}.csv")
                    df.to_csv(out_csv, index=False)

print("Pose keypoint extraction complete! CSVs saved in /content/pose_csv_dataset")
# Out:
# Processing kettlebell_swings_2kg_8_102...
# Processing kettlebell_swings_4kg_3_18...
# Processing kettlebell_swings_2kg_4_114...
# Processing kettlebell_swings_6kg_2_102...
# Processing kettlebell_swings_8kg_8_102...
# Processing kettlebell_swings_6kg_7_114...
# Processing kettlebell_swings_6kg_1_114...
# Processing kettlebell_swings_12kg_2_102...
# Processing kettlebell_swings_2kg_2_102...
# Processing kettlebell_swings_2kg_5_102...
# Processing kettlebell_swings_4kg_2_102...
# Processing kettlebell_swings_6kg_5_102...
# Processing kettlebell_swings_8kg_9_18...
# Processing kettlebell_swings_12kg_4_114...
# Processing kettlebell_swings_8kg_2_102...
# Processing kettlebell_swings_8kg_7_114...
# Processing kettlebell_swings_2kg_1_114...
# Processing kettlebell_swings_6kg_8_102...
# Processing kettlebell_swings_4kg_4_114...
# Processing kettlebell_swings_6kg_3_18...
# Processing kettlebell_swings_6kg_9_18...
# Processing kettlebell_swings_6kg_4_114...
# Processing kettlebell_swings_4kg_6_18...
# Processing kettlebell_swings_4kg_7_114...
# Processing kettlebell_swings_2kg_6_18...
# Processing kettlebell_swings_12kg_6_18...
# Processing kettlebell_swings_4kg_5_102...
# Processing kettlebell_swings_4kg_1_114...
# Processing kettlebell_swings_4kg_8_102...
# Processing kettlebell_swings_12kg_7_114...
# Processing kettlebell_swings_4kg_9_18...
# Processing kettlebell_swings_8kg_5_102...
# Processing kettlebell_swings_8kg_3_18...
# Processing kettlebell_swings_12kg_1_114...
# Processing kettlebell_swings_8kg_6_18...
# Processing kettlebell_swings_12kg_8_102...
# Processing kettlebell_swings_12kg_5_102...
# Processing kettlebell_swings_2kg_9_18...
# Processing kettlebell_swings_12kg_9_18...
# Processing kettlebell_swings_2kg_7_114...
# Processing kettlebell_swings_2kg_3_18...
# Processing kettlebell_swings_6kg_6_18...
# Processing kettlebell_swings_8kg_4_114...
# Processing kettlebell_swings_8kg_1_114...
# Processing kettlebell_swings_12kg_3_18...
# Processing Bicep_Curls_142_196...
# Processing Bicep_Curls_223_117...
# Processing Bicep_Curls_203_110...
# Processing Bicep_Curls_188_111...
# Processing Bicep_Curls_186_102...
# Processing Bicep_Curls_111_117...
# Processing Bicep_Curls_162_102...
# Processing Bicep_Curls_151_117...
# Processing Bicep_Curls_212_111...
# Processing Bicep_Curls_167_117...
# Processing Bicep_Curls_222_196...
# Processing Bicep_Curls_211_110...
# Processing Bicep_Curls_207_117...
# Processing Bicep_Curls_124_111...
# Processing Bicep_Curls_141_18...
# Processing Bicep_Curls_209_114...
# Processing Bicep_Curls_122_102...
# Processing Bicep_Curls_197_18...
# Processing Bicep_Curls_13_18...
# Processing Bicep_Curls_219_110...
# Processing Bicep_Curls_189_18...
# Processing Bicep_Curls_137_114...
# Processing Bicep_Curls_146_102...
# Processing Bicep_Curls_129_114...
# Processing Bicep_Curls_120_112...
# Processing Bicep_Curls_152_112...
# Processing Bicep_Curls_201_114...
# Processing Bicep_Curls_175_117...
# Processing Bicep_Curls_161_114...
# Processing Bicep_Curls_173_18...
# Processing Bicep_Curls_231_117...
# Processing Bicep_Curls_114_102...
# Processing Bicep_Curls_100_111...
# Processing Bicep_Curls_127_117...
# Processing Bicep_Curls_12_111...
# Processing Bicep_Curls_224_112...
# Processing Bicep_Curls_177_114...
# Processing Bicep_Curls_225_114...
# Processing Bicep_Curls_18_102...
# Processing Bicep_Curls_133_18...
# Processing Bicep_Curls_198_196...
# Processing Bicep_Curls_148_111...
# Processing Bicep_Curls_115_110...
# Processing Bicep_Curls_135_117...
# Processing Bicep_Curls_230_196...
# Processing Bicep_Curls_178_102...
# Processing Bicep_Curls_206_196...
# Processing Bicep_Curls_164_111...
# Processing Bicep_Curls_169_114...
# Processing Bicep_Curls_194_102...
# Processing Bicep_Curls_217_114...
# Processing Bicep_Curls_102_196...
# Processing Bicep_Curls_208_112...
# Processing Bicep_Curls_126_196...
# Processing Bicep_Curls_187_110...
# Processing Bicep_Curls_215_117...
# Processing Bicep_Curls_153_114...
# Processing Bicep_Curls_130_102...
# Processing Bicep_Curls_214_196...
# Processing Bicep_Curls_21_18...
# Processing Bicep_Curls_221_18...
# Processing Bicep_Curls_144_112...
# Processing Bicep_Curls_1_114...
# Processing Bicep_Curls_149_18...
# Processing Bicep_Curls_171_110...
# Processing Bicep_Curls_155_110...
# Processing Bicep_Curls_228_111...
# Processing Bicep_Curls_110_196...
# Processing Bicep_Curls_168_112...
# Processing Bicep_Curls_22_196...
# Processing Bicep_Curls_103_117...
# Processing Bicep_Curls_181_18...
# Processing Bicep_Curls_11_110...
# Processing Bicep_Curls_119_117...
# Processing Bicep_Curls_213_18...
# Processing Bicep_Curls_192_112...
# Processing Bicep_Curls_160_112...
# Processing Bicep_Curls_163_110...
# Processing Bicep_Curls_204_111...
# Processing Bicep_Curls_139_110...
# Processing Bicep_Curls_165_18...
# Processing Bicep_Curls_107_110...
# Processing Bicep_Curls_116_111...
# Processing Bicep_Curls_196_111...
# Processing Bicep_Curls_179_110...
# Processing Bicep_Curls_195_110...
# Processing Bicep_Curls_147_110...
# Processing Bicep_Curls_183_117...
# Processing Bicep_Curls_117_18...
# Processing Bicep_Curls_15_117...
# Processing Bicep_Curls_191_117...
# Processing Bicep_Curls_170_102...
# Processing Bicep_Curls_156_111...
# Processing Bicep_Curls_229_18...
# Processing Bicep_Curls_16_112...
# Processing Bicep_Curls_118_196...
# Processing Bicep_Curls_10_102...
# Processing Bicep_Curls_106_102...
# Processing Bicep_Curls_157_18...
# Processing Bicep_Curls_158_196...
# Processing Bicep_Curls_123_110...
# Processing Bicep_Curls_145_114...
# Processing Bicep_Curls_200_112...
# Processing Bicep_Curls_154_102...
# Processing Bicep_Curls_109_18...
# Processing Bicep_Curls_226_102...
# Processing Bicep_Curls_113_114...
# Processing Bicep_Curls_202_102...
# Processing Bicep_Curls_159_117...
# Processing Bicep_Curls_140_111...
# Processing Bicep_Curls_176_112...
# Processing Bicep_Curls_17_114...
# Processing Bicep_Curls_108_111...
# Processing Bicep_Curls_182_196...
# Processing Bicep_Curls_205_18...
# Processing Bicep_Curls_128_112...
# Processing Bicep_Curls_134_196...
# Processing Bicep_Curls_131_110...
# Processing Bicep_Curls_143_117...
# Processing Bicep_Curls_105_114...
# Processing Bicep_Curls_185_114...
# Processing Bicep_Curls_190_196...
# Processing Bicep_Curls_174_196...
# Processing Bicep_Curls_184_112...
# Processing Bicep_Curls_19_110...
# Processing Bicep_Curls_136_112...
# Processing Bicep_Curls_104_112...
# Processing Bicep_Curls_20_111...
# Processing Bicep_Curls_180_111...
# Processing Bicep_Curls_14_196...
# Processing Bicep_Curls_218_102...
# Processing Bicep_Curls_132_111...
# Processing Bicep_Curls_138_102...
# Processing Bicep_Curls_210_102...
# Processing Bicep_Curls_112_112...
# Processing Bicep_Curls_166_196...
# Processing Bicep_Curls_150_196...
# Processing Bicep_Curls_172_111...
# Processing Bicep_Curls_220_111...
# Processing Bicep_Curls_125_18...
# Processing Bicep_Curls_121_114...
# Processing Bicep_Curls_216_112...
# Processing Bicep_Curls_227_110...
# Processing Bicep_Curls_101_18...
# Processing Bicep_Curls_199_117...
# Processing Shoulder_Press_242_111...
# Processing Shoulder_Press_124_111...
# Processing Shoulder_Press_84_111...
# Processing Shoulder_Press_144_112...
# Processing Shoulder_Press_90_102...
# Processing Shoulder_Press_243_18...
# Processing Shoulder_Press_47_117...
# Processing Shoulder_Press_214_112...
# Processing Shoulder_Press_185_110...
# Processing Shoulder_Press_246_112...
# Processing Shoulder_Press_187_18...
# Processing Shoulder_Press_148_111...
# Processing Shoulder_Press_70_196...
# Processing Shoulder_Press_180_196...
# Processing Shoulder_Press_224_102...
# Processing Shoulder_Press_192_102...
# Processing Shoulder_Press_209_110...
# Processing Shoulder_Press_19_110...
# Processing Shoulder_Press_230_112...
# Processing Shoulder_Press_46_196...
# Processing Shoulder_Press_183_114...
# Processing Shoulder_Press_127_117...
# Processing Shoulder_Press_81_114...
# Processing Shoulder_Press_163_110...
# Processing Shoulder_Press_91_110...
# Processing Shoulder_Press_229_117...
# Processing Shoulder_Press_188_196...
# Processing Shoulder_Press_131_110...
# Processing Shoulder_Press_116_111...
# Processing Shoulder_Press_49_114...
# Processing Shoulder_Press_138_102...
# Processing Shoulder_Press_222_112...
# Processing Shoulder_Press_152_112...
# Processing Shoulder_Press_219_18...
# Processing Shoulder_Press_6_196...
# Processing Shoulder_Press_141_18...
# Processing Shoulder_Press_27_110...
# Processing Shoulder_Press_83_110...
# Processing Shoulder_Press_139_110...
# Processing Shoulder_Press_190_112...
# Processing Shoulder_Press_232_102...
# Processing Shoulder_Press_171_18...
# Processing Shoulder_Press_103_117...
# Processing Shoulder_Press_206_112...
# Processing Shoulder_Press_235_18...
# Processing Shoulder_Press_160_112...
# Processing Shoulder_Press_238_112...
# Processing Shoulder_Press_234_111...
# Processing Shoulder_Press_105_114...
# Processing Shoulder_Press_97_114...
# Processing Shoulder_Press_205_117...
# Processing Shoulder_Press_228_196...
# Processing Shoulder_Press_218_111...
# Processing Shoulder_Press_1_114...
# Processing Shoulder_Press_170_111...
# Processing Shoulder_Press_182_112...
# Processing Shoulder_Press_237_117...
# Processing Shoulder_Press_175_114...
# Processing Shoulder_Press_5_18...
# Processing Shoulder_Press_64_112...
# Processing Shoulder_Press_221_117...
# Processing Shoulder_Press_169_110...
# Processing Shoulder_Press_239_114...
# Processing Shoulder_Press_79_117...
# Processing Shoulder_Press_74_102...
# Processing Shoulder_Press_60_111...
# Processing Shoulder_Press_48_112...
# Processing Shoulder_Press_71_117...
# Processing Shoulder_Press_3_110...
# Processing Shoulder_Press_208_102...
# Processing Shoulder_Press_69_18...
# Processing Shoulder_Press_244_196...
# Processing Shoulder_Press_39_117...
# Processing Shoulder_Press_52_111...
# Processing Shoulder_Press_158_196...
# Processing Shoulder_Press_133_18...
# Processing Shoulder_Press_88_112...
# Processing Shoulder_Press_117_18...
# Processing Shoulder_Press_55_117...
# Processing Shoulder_Press_40_112...
# Processing Shoulder_Press_199_114...
# Processing Shoulder_Press_126_196...
# Processing Shoulder_Press_123_110...
# Processing Shoulder_Press_122_102...
# Processing Shoulder_Press_119_117...
# Processing Shoulder_Press_33_114...
# Processing Shoulder_Press_197_117...
# Processing Shoulder_Press_193_110...
# Processing Shoulder_Press_198_112...
# Processing Shoulder_Press_76_111...
# Processing Shoulder_Press_203_18...
# Processing Shoulder_Press_245_117...
# Processing Shoulder_Press_140_111...
# Processing Shoulder_Press_4_111...
# Processing Shoulder_Press_89_114...
# Processing Shoulder_Press_54_196...
# Processing Shoulder_Press_121_114...
# Processing Shoulder_Press_196_196...
# Processing Shoulder_Press_165_18...
# Processing Shoulder_Press_189_117...
# Processing Shoulder_Press_194_111...
# Processing Shoulder_Press_151_117...
# Processing Shoulder_Press_136_112...
# Processing Shoulder_Press_186_111...
# Processing Shoulder_Press_11_110...
# Processing Shoulder_Press_213_117...
# Processing Shoulder_Press_168_102...
# Processing Shoulder_Press_174_112...
# Processing Shoulder_Press_233_110...
# Processing Shoulder_Press_14_196...
# Processing Shoulder_Press_78_196...
# Processing Shoulder_Press_216_102...
# Processing Shoulder_Press_220_196...
# Processing Shoulder_Press_142_196...
# Processing Shoulder_Press_43_110...
# Processing Shoulder_Press_100_111...
# Processing Shoulder_Press_107_110...
# Processing Shoulder_Press_181_117...
# Processing Shoulder_Press_177_110...
# Processing Shoulder_Press_98_102...
# Processing Shoulder_Press_17_114...
# Processing Shoulder_Press_75_110...
# Processing Shoulder_Press_129_114...
# Processing Shoulder_Press_31_117...
# Processing Shoulder_Press_173_117...
# Processing Shoulder_Press_108_111...
# Processing Shoulder_Press_113_114...
# Processing Shoulder_Press_110_196...
# Processing Shoulder_Press_23_117...
# Processing Shoulder_Press_195_18...
# Processing Shoulder_Press_150_196...
# Processing Shoulder_Press_104_112...
# Processing Shoulder_Press_179_18...
# Processing Shoulder_Press_67_110...
# Processing Shoulder_Press_35_110...
# Processing Shoulder_Press_99_110...
# Processing Shoulder_Press_120_112...
# Processing Shoulder_Press_212_196...
# Processing Shoulder_Press_201_110...
# Processing Shoulder_Press_202_111...
# Processing Shoulder_Press_30_196...
# Processing Shoulder_Press_184_102...
# Processing Shoulder_Press_86_196...
# Processing Shoulder_Press_77_18...
# Processing Shoulder_Press_134_196...
# Processing Shoulder_Press_153_114...
# Processing Shoulder_Press_236_196...
# Processing Shoulder_Press_225_110...
# Processing Shoulder_Press_36_111...
# Processing Shoulder_Press_164_111...
# Processing Shoulder_Press_147_110...
# Processing Shoulder_Press_241_110...
# Processing Shoulder_Press_9_114...
# Processing Shoulder_Press_159_117...
# Processing Shoulder_Press_63_117...
# Processing Shoulder_Press_32_112...
# Processing Shoulder_Press_16_112...
# Processing Shoulder_Press_7_117...
# Processing Shoulder_Press_226_111...
# Processing Shoulder_Press_130_102...
# Processing Shoulder_Press_125_18...
# Processing Shoulder_Press_73_114...
# Processing Shoulder_Press_166_196...
# Processing Shoulder_Press_66_102...
# Processing Shoulder_Press_65_114...
# Processing Shoulder_Press_172_196...
# Processing Shoulder_Press_204_196...
# Processing Shoulder_Press_95_117...
# Processing Shoulder_Press_211_18...
# Processing Shoulder_Press_82_102...
# Processing Shoulder_Press_80_112...
# Processing Shoulder_Press_41_114...
# Processing Shoulder_Press_59_110...
# Processing Shoulder_Press_44_111...
# Processing Shoulder_Press_28_111...
# Processing Shoulder_Press_200_102...
# Processing Shoulder_Press_93_18...
# Processing Shoulder_Press_155_110...
# Processing Shoulder_Press_102_196...
# Processing Shoulder_Press_154_102...
# Processing Shoulder_Press_72_112...
# Processing Shoulder_Press_115_110...
# Processing Shoulder_Press_157_18...
# Processing Shoulder_Press_12_111...
# Processing Shoulder_Press_68_111...
# Processing Shoulder_Press_8_112...
# Processing Shoulder_Press_25_114...
# Processing Shoulder_Press_24_112...
# Processing Shoulder_Press_132_111...
# Processing Shoulder_Press_207_114...
# Processing Shoulder_Press_92_111...
# Processing Shoulder_Press_231_114...
# Processing Shoulder_Press_94_196...
# Processing Shoulder_Press_178_111...
# Processing Shoulder_Press_137_114...
# Processing Shoulder_Press_112_112...
# Processing Shoulder_Press_15_117...
# Processing Shoulder_Press_217_110...
# Processing Shoulder_Press_56_112...
# Processing Shoulder_Press_51_110...
# Processing Shoulder_Press_62_196...
# Processing Shoulder_Press_128_112...
# Processing Shoulder_Press_227_18...
# Processing Shoulder_Press_149_18...
# Processing Shoulder_Press_38_196...
# Processing Shoulder_Press_96_112...
# Processing Shoulder_Press_156_111...
# Processing Shoulder_Press_101_18...
# Processing Shoulder_Press_106_102...
# Processing Shoulder_Press_240_102...
# Processing Shoulder_Press_145_114...
# Processing Shoulder_Press_87_117...
# Processing Shoulder_Press_114_102...
# Processing Shoulder_Press_210_111...
# Processing Shoulder_Press_176_102...
# Processing Shoulder_Press_143_117...
# Processing Shoulder_Press_22_196...
# Processing Shoulder_Press_109_18...
# Processing Shoulder_Press_215_114...
# Processing Shoulder_Press_118_196...
# Processing Shoulder_Press_146_102...
# Processing Shoulder_Press_111_117...
# Processing Shoulder_Press_20_111...
# Processing Shoulder_Press_57_114...
# Processing Shoulder_Press_85_18...
# Processing Shoulder_Press_191_114...
# Processing Shoulder_Press_135_117...
# Processing Shoulder_Press_223_114...
# Processing Shoulder_Press_167_114...
# Processing Front_Raise_150_196...
# Processing Front_Raise_126_196...
# Processing Front_Raise_135_110...
# Processing Front_Raise_83_18...
# Processing Front_Raise_166_111...
# Processing Front_Raise_63_110...
# Processing Front_Raise_88_111...
# Processing Front_Raise_13_114...
# Processing Front_Raise_69_110...
# Processing Front_Raise_172_111...
# Processing Front_Raise_159_110...
# Processing Front_Raise_144_196...
# Processing Front_Raise_87_110...
# Processing Front_Raise_132_196...
# Processing Front_Raise_180_196...
# Processing Front_Raise_61_114...
# Processing Front_Raise_129_110...
# Processing Front_Raise_143_18...
# Processing Front_Raise_85_114...
# Processing Front_Raise_89_18...
# Processing Front_Raise_56_102...
# Processing Front_Raise_154_111...
# Processing Front_Raise_106_111...
# Processing Front_Raise_138_196...
# Processing Front_Raise_151_114...
# Processing Front_Raise_131_18...
# Processing Front_Raise_153_110...
# Processing Front_Raise_163_114...
# Processing Front_Raise_28_111...
# Processing Front_Raise_82_111...
# Processing Front_Raise_86_102...
# Processing Front_Raise_16_111...
# Processing Front_Raise_145_114...
# Processing Front_Raise_15_110...
# Processing Front_Raise_59_18...
# Processing Front_Raise_23_18...
# Processing Front_Raise_5_18...
# Processing Front_Raise_67_114...
# Processing Front_Raise_142_111...
# Processing Front_Raise_60_196...
# Processing Front_Raise_137_18...
# Processing Front_Raise_8_102...
# Processing Front_Raise_11_18...
# Processing Front_Raise_162_196...
# Processing Front_Raise_125_18...
# Processing Front_Raise_114_196...
# Processing Front_Raise_42_196...
# Processing Front_Raise_148_111...
# Processing Front_Raise_77_18...
# Processing Front_Raise_113_18...
# Processing Front_Raise_64_111...
# Processing Front_Raise_173_18...
# Processing Front_Raise_53_18...
# Processing Front_Raise_171_110...
# Processing Front_Raise_27_110...
# Processing Front_Raise_169_114...
# Processing Front_Raise_65_18...
# Processing Front_Raise_71_18...
# Processing Front_Raise_179_18...
# Processing Front_Raise_161_18...
# Processing Front_Raise_17_18...
# Processing Front_Raise_32_102...
# Processing Front_Raise_104_102...
# Processing Front_Raise_177_110...
# Processing Front_Raise_39_110...
# Processing Front_Raise_74_102...
# Processing Front_Raise_44_102...
# Processing Front_Raise_52_111...
# Processing Front_Raise_57_110...
# Processing Front_Raise_40_111...
# Processing Front_Raise_6_196...
# Processing Front_Raise_111_110...
# Processing Front_Raise_117_110...
# Processing Front_Raise_146_102...
# Processing Front_Raise_33_110...
# Processing Front_Raise_109_114...
# Processing Front_Raise_100_111...
# Processing Front_Raise_37_114...
# Processing Front_Raise_73_114...
# Processing Front_Raise_128_102...
# Processing Front_Raise_70_111...
# Processing Front_Raise_58_111...
# Processing Front_Raise_164_102...
# Processing Front_Raise_155_18...
# Processing Front_Raise_19_114...
# Processing Front_Raise_124_111...
# Processing Front_Raise_157_114...
# Processing Front_Raise_178_111...
# Processing Front_Raise_167_18...
# Processing Front_Raise_116_102...
# Processing Front_Raise_66_196...
# Processing Front_Raise_79_114...
# Processing Front_Raise_25_114...
# Processing Front_Raise_141_110...
# Processing Front_Raise_156_196...
# Processing Front_Raise_103_114...
# Processing Front_Raise_30_196...
# Processing Front_Raise_174_196...
# Processing Front_Raise_121_114...
# Processing Front_Raise_134_102...
# Processing Front_Raise_43_114...
# Processing Front_Raise_133_114...
# Processing Front_Raise_107_18...
# Processing Front_Raise_22_111...
# Processing Front_Raise_3_110...
# Processing Front_Raise_26_102...
# Processing Front_Raise_119_18...
# Processing Front_Raise_102_196...
# Processing Front_Raise_101_18...
# Processing Front_Raise_24_196...
# Processing Front_Raise_175_114...
# Processing Front_Raise_108_196...
# Processing Front_Raise_29_18...
# Processing Front_Raise_50_102...
# Processing Front_Raise_12_196...
# Processing Front_Raise_35_18...
# Processing Front_Raise_18_196...
# Processing Front_Raise_41_18...
# Processing Front_Raise_170_102...
# Processing Front_Raise_14_102...
# Processing Front_Raise_51_110...
# Processing Front_Raise_49_114...
# Processing Front_Raise_76_111...
# Processing Front_Raise_21_110...
# Processing Front_Raise_122_102...
# Processing Front_Raise_81_110...
# Processing Front_Raise_80_102...
# Processing Front_Raise_72_196...
# Processing Front_Raise_47_18...
# Processing Front_Raise_168_196...
# Processing Front_Raise_84_196...
# Processing Front_Raise_38_102...
# Processing Front_Raise_62_102...
# Processing Front_Raise_139_114...
# Processing Front_Raise_130_111...
# Processing Front_Raise_115_114...
# Processing Front_Raise_48_196...
# Processing Front_Raise_75_110...
# Processing Front_Raise_105_110...
# Processing Front_Raise_54_196...
# Processing Front_Raise_147_110...
# Processing Front_Raise_55_114...
# Processing Front_Raise_2_102...
# Processing Front_Raise_136_111...
# Processing Front_Raise_46_111...
# Processing Front_Raise_152_102...
# Processing Front_Raise_123_110...
# Processing Front_Raise_7_114...
# Processing Front_Raise_140_102...
# Processing Front_Raise_112_111...
# Processing Front_Raise_160_111...
# Processing Front_Raise_149_18...
# Processing Front_Raise_118_111...
# Processing Front_Raise_110_102...
# Processing Front_Raise_165_110...
# Processing Front_Raise_34_111...
# Processing Front_Raise_4_111...
# Processing Front_Raise_1_114...
# Processing Front_Raise_78_196...
# Processing Front_Raise_176_102...
# Processing Front_Raise_36_196...
# Processing Front_Raise_127_114...
# Processing Front_Raise_120_196...
# Processing Front_Raise_10_111...
# Processing Front_Raise_68_102...
# Processing Front_Raise_31_114...
# Processing Front_Raise_158_102...
# Processing Front_Raise_20_102...
# Processing Front_Raise_45_110...
# Processing Bench_Press_135_110...
# Processing Bench_Press_83_18...
# Processing Bench_Press_37_114...
# Processing Bench_Press_176_102...
# Processing Bench_Press_79_114...
# Processing Bench_Press_128_102...
# Processing Bench_Press_49_114...
# Processing Bench_Press_55_114...
# Processing Bench_Press_5_18...
# Processing Bench_Press_142_111...
# Processing Bench_Press_134_102...
# Processing Bench_Press_57_110...
# Processing Bench_Press_172_111...
# Processing Bench_Press_144_196...
# Processing Bench_Press_107_18...
# Processing Bench_Press_35_18...
# Processing Bench_Press_7_114...
# Processing Bench_Press_27_110...
# Processing Bench_Press_41_18...
# Processing Bench_Press_102_196...
# Processing Bench_Press_100_111...
# Processing Bench_Press_158_102...
# Processing Bench_Press_56_102...
# Processing Bench_Press_6_196...
# Processing Bench_Press_111_110...
# Processing Bench_Press_160_111...
# Processing Bench_Press_124_111...
# Processing Bench_Press_126_196...
# Processing Bench_Press_14_102...
# Processing Bench_Press_108_196...
# Processing Bench_Press_86_102...
# Processing Bench_Press_69_110...
# Processing Bench_Press_119_18...
# Processing Bench_Press_167_18...
# Processing Bench_Press_42_196...
# Processing Bench_Press_166_111...
# Processing Bench_Press_44_102...
# Processing Bench_Press_136_111...
# Processing Bench_Press_169_114...
# Processing Bench_Press_116_102...
# Processing Bench_Press_19_114...
# Processing Bench_Press_125_18...
# Processing Bench_Press_17_18...
# Processing Bench_Press_1_114...
# Processing Bench_Press_171_110...
# Processing Bench_Press_23_18...
# Processing Bench_Press_39_110...
# Processing Bench_Press_24_196...
# Processing Bench_Press_105_110...
# Processing Bench_Press_147_110...
# Processing Bench_Press_132_196...
# Processing Bench_Press_127_114...
# Processing Bench_Press_180_196...
# Processing Bench_Press_40_111...
# Processing Bench_Press_106_111...
# Processing Bench_Press_77_18...
# Processing Bench_Press_38_102...
# Processing Bench_Press_13_114...
# Processing Bench_Press_115_114...
# Processing Bench_Press_82_111...
# Processing Bench_Press_11_18...
# Processing Bench_Press_112_111...
# Processing Bench_Press_20_102...
# Processing Bench_Press_155_18...
# Processing Bench_Press_178_111...
# Processing Bench_Press_110_102...
# Processing Bench_Press_177_110...
# Processing Bench_Press_3_110...
# Processing Bench_Press_173_18...
# Processing Bench_Press_62_102...
# Processing Bench_Press_146_102...
# Processing Bench_Press_114_196...
# Processing Bench_Press_156_196...
# Processing Bench_Press_36_196...
# Processing Bench_Press_32_102...
# Processing Bench_Press_4_111...
# Processing Bench_Press_31_114...
# Processing Bench_Press_149_18...
# Processing Bench_Press_152_102...
# Processing Bench_Press_159_110...
# Processing Bench_Press_51_110...
# Processing Bench_Press_151_114...
# Processing Bench_Press_165_110...
# Processing Bench_Press_161_18...
# Processing Bench_Press_12_196...
# Processing Bench_Press_164_102...
# Processing Bench_Press_46_111...
# Processing Bench_Press_123_110...
# Processing Bench_Press_141_110...
# Processing Bench_Press_48_196...
# Processing Bench_Press_81_110...
# Processing Bench_Press_78_196...
# Processing Bench_Press_139_114...
# Processing Bench_Press_129_110...
# Processing Bench_Press_45_110...
# Processing Bench_Press_87_110...
# Processing Bench_Press_145_114...
# Processing Bench_Press_157_114...
# Processing Bench_Press_163_114...
# Processing Bench_Press_153_110...
# Processing Bench_Press_84_196...
# Processing Bench_Press_168_196...
# Processing Bench_Press_74_102...
# Processing Bench_Press_71_18...
# Processing Bench_Press_61_114...
# Processing Bench_Press_154_111...
# Processing Bench_Press_101_18...
# Processing Bench_Press_53_18...
# Processing Bench_Press_130_111...
# Processing Bench_Press_138_196...
# Processing Bench_Press_34_111...
# Processing Bench_Press_59_18...
# Processing Bench_Press_174_196...
# Processing Bench_Press_75_110...
# Processing Bench_Press_73_114...
# Processing Bench_Press_47_18...
# Processing Bench_Press_33_110...
# Processing Bench_Press_60_196...
# Processing Bench_Press_15_110...
# Processing Bench_Press_70_111...
# Processing Bench_Press_140_102...
# Processing Bench_Press_68_102...
# Processing Bench_Press_133_114...
# Processing Bench_Press_2_102...
# Processing Bench_Press_121_114...
# Processing Bench_Press_8_102...
# Processing Bench_Press_26_102...
# Processing Bench_Press_118_111...
# Processing Bench_Press_16_111...
# Processing Bench_Press_150_196...
# Processing Bench_Press_54_196...
# Processing Bench_Press_50_102...
# Processing Bench_Press_22_111...
# Processing Bench_Press_52_111...
# Processing Bench_Press_29_18...
# Processing Bench_Press_25_114...
# Processing Bench_Press_143_18...
# Processing Bench_Press_28_111...
# Processing Bench_Press_65_18...
# Processing Bench_Press_66_196...
# Processing Bench_Press_170_102...
# Processing Bench_Press_175_114...
# Processing Bench_Press_117_110...
# Processing Bench_Press_76_111...
# Processing Bench_Press_131_18...
# Processing Bench_Press_162_196...
# Processing Bench_Press_21_110...
# Processing Bench_Press_67_114...
# Processing Bench_Press_43_114...
# Processing Bench_Press_89_18...
# Processing Bench_Press_148_111...
# Processing Bench_Press_122_102...
# Processing Bench_Press_63_110...
# Processing Bench_Press_88_111...
# Processing Bench_Press_30_196...
# Processing Bench_Press_179_18...
# Processing Bench_Press_85_114...
# Processing Bench_Press_58_111...
# Processing Bench_Press_137_18...
# Processing Bench_Press_109_114...
# Processing Bench_Press_103_114...
# Processing Bench_Press_104_102...
# Processing Bench_Press_72_196...
# Processing Bench_Press_80_102...
# Processing Bench_Press_64_111...
# Processing Bench_Press_18_196...
# Processing Bench_Press_10_111...
# Processing Bench_Press_120_196...
# Processing Bench_Press_113_18...
# Processing Bent_Over_Rows_116_102...
# Processing Bent_Over_Rows_167_18...
# Processing Bent_Over_Rows_20_102...
# Processing Bent_Over_Rows_9_110...
# Processing Bent_Over_Rows_34_111...
# Processing Bent_Over_Rows_131_18...
# Processing Bent_Over_Rows_105_110...
# Processing Bent_Over_Rows_80_102...
# Processing Bent_Over_Rows_69_110...
# Processing Bent_Over_Rows_107_18...
# Processing Bent_Over_Rows_70_111...
# Processing Bent_Over_Rows_29_18...
# Processing Bent_Over_Rows_40_111...
# Processing Bent_Over_Rows_124_111...
# Processing Bent_Over_Rows_127_114...
# Processing Bent_Over_Rows_143_18...
# Processing Bent_Over_Rows_13_114...
# Processing Bent_Over_Rows_97_114...
# Processing Bent_Over_Rows_163_114...
# Processing Bent_Over_Rows_115_114...
# Processing Bent_Over_Rows_54_196...
# Processing Bent_Over_Rows_171_110...
# Processing Bent_Over_Rows_42_196...
# Processing Bent_Over_Rows_3_110...
# Processing Bent_Over_Rows_87_110...
# Processing Bent_Over_Rows_27_110...
# Processing Bent_Over_Rows_137_18...
# Processing Bent_Over_Rows_67_114...
# Processing Bent_Over_Rows_72_196...
# Processing Bent_Over_Rows_168_196...
# Processing Bent_Over_Rows_74_102...
# Processing Bent_Over_Rows_50_102...
# Processing Bent_Over_Rows_169_114...
# Processing Bent_Over_Rows_123_110...
# Processing Bent_Over_Rows_134_102...
# Processing Bent_Over_Rows_53_18...
# Processing Bent_Over_Rows_153_110...
# Processing Bent_Over_Rows_43_114...
# Processing Bent_Over_Rows_119_18...
# Processing Bent_Over_Rows_1_114...
# Processing Bent_Over_Rows_2_102...
# Processing Bent_Over_Rows_78_196...
# Processing Bent_Over_Rows_159_110...
# Processing Bent_Over_Rows_10_111...
# Processing Bent_Over_Rows_91_114...
# Processing Bent_Over_Rows_17_18...
# Processing Bent_Over_Rows_37_114...
# Processing Bent_Over_Rows_152_102...
# Processing Bent_Over_Rows_172_111...
# Processing Bent_Over_Rows_146_102...
# Processing Bent_Over_Rows_93_110...
# Processing Bent_Over_Rows_7_114...
# Processing Bent_Over_Rows_15_110...
# Processing Bent_Over_Rows_4_111...
# Processing Bent_Over_Rows_142_111...
# Processing Bent_Over_Rows_82_111...
# Processing Bent_Over_Rows_59_18...
# Processing Bent_Over_Rows_151_114...
# Processing Bent_Over_Rows_47_18...
# Processing Bent_Over_Rows_8_102...
# Processing Bent_Over_Rows_83_18...
# Processing Bent_Over_Rows_103_114...
# Processing Bent_Over_Rows_62_102...
# Processing Bent_Over_Rows_148_111...
# Processing Bent_Over_Rows_130_111...
# Processing Bent_Over_Rows_101_18...
# Processing Bent_Over_Rows_26_102...
# Processing Bent_Over_Rows_104_102...
# Processing Bent_Over_Rows_113_18...
# Processing Bent_Over_Rows_129_110...
# Processing Bent_Over_Rows_140_102...
# Processing Bent_Over_Rows_173_18...
# Processing Bent_Over_Rows_139_114...
# Processing Bent_Over_Rows_108_196...
# Processing Bent_Over_Rows_149_18...
# Processing Bent_Over_Rows_55_114...
# Processing Bent_Over_Rows_138_196...
# Processing Bent_Over_Rows_6_196...
# Processing Bent_Over_Rows_63_110...
# Processing Bent_Over_Rows_71_18...
# Processing Bent_Over_Rows_128_102...
# Processing Bent_Over_Rows_49_114...
# Processing Bent_Over_Rows_141_110...
# Processing Bent_Over_Rows_133_114...
# Processing Bent_Over_Rows_66_196...
# Processing Bent_Over_Rows_174_196...
# Processing Bent_Over_Rows_25_114...
# Processing Bent_Over_Rows_99_110...
# Processing Bent_Over_Rows_156_196...
# Processing Bent_Over_Rows_177_110...
# Processing Bent_Over_Rows_147_110...
# Processing Bent_Over_Rows_161_18...
# Processing Bent_Over_Rows_61_114...
# Processing Bent_Over_Rows_166_111...
# Processing Bent_Over_Rows_65_18...
# Processing Bent_Over_Rows_114_196...
# Processing Bent_Over_Rows_77_18...
# Processing Bent_Over_Rows_68_102...
# Processing Bent_Over_Rows_45_110...
# Processing Bent_Over_Rows_106_111...
# Processing Bent_Over_Rows_35_18...
# Processing Bent_Over_Rows_44_102...
# Processing Bent_Over_Rows_30_196...
# Processing Bent_Over_Rows_11_18...
# Processing Bent_Over_Rows_164_102...
# Processing Bent_Over_Rows_175_114...
# Processing Bent_Over_Rows_38_102...
# Processing Bent_Over_Rows_75_110...
# Processing Bent_Over_Rows_165_110...
# Processing Bent_Over_Rows_150_196...
# Processing Bent_Over_Rows_94_111...
# Processing Bent_Over_Rows_23_18...
# Processing Bent_Over_Rows_57_110...
# Processing Bent_Over_Rows_162_196...
# Processing Bent_Over_Rows_88_111...
# Processing Bent_Over_Rows_102_196...
# Processing Bent_Over_Rows_122_102...
# Processing Bent_Over_Rows_145_114...
# Processing Bent_Over_Rows_46_111...
# Processing Bent_Over_Rows_125_18...
# Processing Bent_Over_Rows_52_111...
# Processing Bent_Over_Rows_58_111...
# Processing Bent_Over_Rows_73_114...
# Processing Bent_Over_Rows_16_111...
# Processing Bent_Over_Rows_126_196...
# Processing Bent_Over_Rows_18_196...
# Processing Bent_Over_Rows_12_196...
# Processing Bent_Over_Rows_39_110...
# Processing Bent_Over_Rows_90_196...
# Processing Bent_Over_Rows_79_114...
# Processing Bent_Over_Rows_135_110...
# Processing Bent_Over_Rows_92_102...
# Processing Bent_Over_Rows_155_18...
# Processing Bent_Over_Rows_5_18...
# Processing Bent_Over_Rows_154_111...
# Processing Bent_Over_Rows_14_102...
# Processing Bent_Over_Rows_136_111...
# Processing Bent_Over_Rows_76_111...
# Processing Bent_Over_Rows_41_18...
# Processing Bent_Over_Rows_158_102...
# Processing Bent_Over_Rows_100_111...
# Processing Bent_Over_Rows_21_110...
# Processing Bent_Over_Rows_95_18...
# Processing Bent_Over_Rows_33_110...
# Processing Bent_Over_Rows_109_114...
# Processing Bent_Over_Rows_117_110...
# Processing Bent_Over_Rows_120_196...
# Processing Bent_Over_Rows_22_111...
# Processing Bent_Over_Rows_89_18...
# Processing Bent_Over_Rows_51_110...
# Processing Bent_Over_Rows_160_111...
# Processing Bent_Over_Rows_180_196...
# Processing Bent_Over_Rows_144_196...
# Processing Bent_Over_Rows_60_196...
# Processing Bent_Over_Rows_176_102...
# Processing Bent_Over_Rows_24_196...
# Processing Bent_Over_Rows_64_111...
# Processing Bent_Over_Rows_179_18...
# Processing Bent_Over_Rows_96_196...
# Processing Bent_Over_Rows_112_111...
# Processing Bent_Over_Rows_56_102...
# Processing Bent_Over_Rows_81_110...
# Processing Bent_Over_Rows_118_111...
# Processing Bent_Over_Rows_48_196...
# Processing Bent_Over_Rows_36_196...
# Processing Bent_Over_Rows_32_102...
# Processing Bent_Over_Rows_178_111...
# Processing Bent_Over_Rows_132_196...
# Processing Bent_Over_Rows_85_114...
# Processing Bent_Over_Rows_84_196...
# Processing Bent_Over_Rows_170_102...
# Processing Bent_Over_Rows_86_102...
# Processing Bent_Over_Rows_31_114...
# Processing Bent_Over_Rows_28_111...
# Processing Bent_Over_Rows_19_114...
# Processing Bent_Over_Rows_157_114...
# Processing Bent_Over_Rows_110_102...
# Processing Bent_Over_Rows_98_102...
# Processing Bent_Over_Rows_111_110...
# Processing Bent_Over_Rows_121_114...
# Processing Chest_Flys_11_18...
# Processing Chest_Flys_48_196...
# Processing Chest_Flys_134_102...
# Processing Chest_Flys_123_110...
# Processing Chest_Flys_87_110...
# Processing Chest_Flys_35_18...
# Processing Chest_Flys_61_114...
# Processing Chest_Flys_158_102...
# Processing Chest_Flys_153_110...
# Processing Chest_Flys_178_111...
# Processing Chest_Flys_119_18...
# Processing Chest_Flys_175_114...
# Processing Chest_Flys_171_110...
# Processing Chest_Flys_27_110...
# Processing Chest_Flys_42_196...
# Processing Chest_Flys_79_114...
# Processing Chest_Flys_136_111...
# Processing Chest_Flys_129_110...
# Processing Chest_Flys_103_114...
# Processing Chest_Flys_89_18...
# Processing Chest_Flys_81_110...
# Processing Chest_Flys_88_111...
# Processing Chest_Flys_14_102...
# Processing Chest_Flys_2_102...
# Processing Chest_Flys_162_196...
# Processing Chest_Flys_137_18...
# Processing Chest_Flys_20_102...
# Processing Chest_Flys_148_111...
# Processing Chest_Flys_146_102...
# Processing Chest_Flys_117_110...
# Processing Chest_Flys_127_114...
# Processing Chest_Flys_43_114...
# Processing Chest_Flys_76_111...
# Processing Chest_Flys_52_111...
# Processing Chest_Flys_124_111...
# Processing Chest_Flys_70_111...
# Processing Chest_Flys_155_18...
# Processing Chest_Flys_67_114...
# Processing Chest_Flys_19_114...
# Processing Chest_Flys_82_111...
# Processing Chest_Flys_149_18...
# Processing Chest_Flys_160_111...
# Processing Chest_Flys_104_102...
# Processing Chest_Flys_159_110...
# Processing Chest_Flys_45_110...
# Processing Chest_Flys_105_110...
# Processing Chest_Flys_47_18...
# Processing Chest_Flys_7_114...
# Processing Chest_Flys_135_110...
# Processing Chest_Flys_116_102...
# Processing Chest_Flys_31_114...
# Processing Chest_Flys_165_110...
# Processing Chest_Flys_100_111...
# Processing Chest_Flys_17_18...
# Processing Chest_Flys_126_196...
# Processing Chest_Flys_168_196...
# Processing Chest_Flys_177_110...
# Processing Chest_Flys_157_114...
# Processing Chest_Flys_114_196...
# Processing Chest_Flys_55_114...
# Processing Chest_Flys_26_102...
# Processing Chest_Flys_110_102...
# Processing Chest_Flys_50_102...
# Processing Chest_Flys_49_114...
# Processing Chest_Flys_112_111...
# Processing Chest_Flys_166_111...
# Processing Chest_Flys_145_114...
# Processing Chest_Flys_163_114...
# Processing Chest_Flys_72_196...
# Processing Chest_Flys_172_111...
# Processing Chest_Flys_130_111...
# Processing Chest_Flys_84_196...
# Processing Chest_Flys_66_196...
# Processing Chest_Flys_142_111...
# Processing Chest_Flys_150_196...
# Processing Chest_Flys_77_18...
# Processing Chest_Flys_74_102...
# Processing Chest_Flys_143_18...
# Processing Chest_Flys_140_102...
# Processing Chest_Flys_33_110...
# Processing Chest_Flys_60_196...
# Processing Chest_Flys_156_196...
# Processing Chest_Flys_13_114...
# Processing Chest_Flys_86_102...
# Processing Chest_Flys_63_110...
# Processing Chest_Flys_40_111...
# Processing Chest_Flys_85_114...
# Processing Chest_Flys_167_18...
# Processing Chest_Flys_10_111...
# Processing Chest_Flys_83_18...
# Processing Chest_Flys_24_196...
# Processing Chest_Flys_101_18...
# Processing Chest_Flys_41_18...
# Processing Chest_Flys_22_111...
# Processing Chest_Flys_122_102...
# Processing Chest_Flys_80_102...
# Processing Chest_Flys_102_196...
# Processing Chest_Flys_107_18...
# Processing Chest_Flys_28_111...
# Processing Chest_Flys_25_114...
# Processing Chest_Flys_39_110...
# Processing Chest_Flys_131_18...
# Processing Chest_Flys_30_196...
# Processing Chest_Flys_154_111...
# Processing Chest_Flys_71_18...
# Processing Chest_Flys_109_114...
# Processing Chest_Flys_179_18...
# Processing Chest_Flys_151_114...
# Processing Chest_Flys_108_196...
# Processing Chest_Flys_64_111...
# Processing Chest_Flys_139_114...
# Processing Chest_Flys_147_110...
# Processing Chest_Flys_174_196...
# Processing Chest_Flys_62_102...
# Processing Chest_Flys_29_18...
# Processing Chest_Flys_21_110...
# Processing Chest_Flys_138_196...
# Processing Chest_Flys_34_111...
# Processing Chest_Flys_44_102...
# Processing Chest_Flys_128_102...
# Processing Chest_Flys_15_110...
# Processing Chest_Flys_73_114...
# Processing Chest_Flys_113_18...
# Processing Chest_Flys_176_102...
# Processing Chest_Flys_46_111...
# Processing Chest_Flys_164_102...
# Processing Chest_Flys_3_110...
# Processing Chest_Flys_56_102...
# Processing Chest_Flys_161_18...
# Processing Chest_Flys_121_114...
# Processing Chest_Flys_58_111...
# Processing Chest_Flys_69_110...
# Processing Chest_Flys_68_102...
# Processing Chest_Flys_36_196...
# Processing Chest_Flys_125_18...
# Processing Chest_Flys_6_196...
# Processing Chest_Flys_169_114...
# Processing Chest_Flys_132_196...
# Processing Chest_Flys_59_18...
# Processing Chest_Flys_152_102...
# Processing Chest_Flys_12_196...
# Processing Chest_Flys_170_102...
# Processing Chest_Flys_5_18...
# Processing Chest_Flys_75_110...
# Processing Chest_Flys_120_196...
# Processing Chest_Flys_32_102...
# Processing Chest_Flys_180_196...
# Processing Chest_Flys_51_110...
# Processing Chest_Flys_141_110...
# Processing Chest_Flys_118_111...
# Processing Chest_Flys_18_196...
# Processing Chest_Flys_54_196...
# Processing Chest_Flys_57_110...
# Processing Chest_Flys_38_102...
# Processing Chest_Flys_144_196...
# Processing Chest_Flys_111_110...
# Processing Chest_Flys_23_18...
# Processing Chest_Flys_133_114...
# Processing Chest_Flys_1_114...
# Processing Chest_Flys_4_111...
# Processing Chest_Flys_115_114...
# Processing Chest_Flys_8_102...
# Processing Chest_Flys_173_18...
# Processing Chest_Flys_53_18...
# Processing Chest_Flys_106_111...
# Processing Chest_Flys_65_18...
# Processing Chest_Flys_78_196...
# Processing Chest_Flys_37_114...
# Processing Chest_Flys_16_111...
# Processing rdl_dumbbell_2.5kg_3_18...
# Processing rdl_dumbbell-10kg_1_114...
# Processing rdl_dumbbell_10kg_3_18...
# Processing rdl_dumbbell_10kg_1_114...
# Processing rdl_dumbbell_1kg_6_18...
# Processing rdl_dumbbell_10kg_2_102...
# Processing rdl_dumbbell_7.5kg_2_102...
# Processing rdl_dumbbell_10kg_4_114...
# Processing rdl_dumbbell_7.5kg_1_114...
# Processing rdl_dumbbell_1kg_8_102...
# Processing rdl_dumbbell_2.5kg_6_18...
# Processing rdl_dumbbell_1kg_9_18...
# Processing rdl_dumbbell_10kg_5_102...
# Processing rdl_dumbbell-10kg_3_18...
# Processing rdl_dumbbell_1kg_5_102...
# Processing rdl_dumbbell_7.5kg_7_114...
# Processing rdl_dumbbell_7.5kg_3_18...
# Processing rdl_dumbbell_2.5kg_5_102...
# Processing rdl_dumbbell_7.5kg_6_18...
# Processing rdl_dumbbell_2.5kg_4_114...
# Processing rdl_dumbbell_2.5kg_9_18...
# Processing rdl_dumbbell_7.5kg_8_102...
# Processing rdl_dumbbell_1kg_7_114...
# Processing rdl_dumbbell_2.5kg_1_114...
# Processing rdl_dumbbell_1kg_1_114...
# Processing rdl_dumbbell_1kg_4_114...
# Processing rdl_dumbbell_10kg_6_18...
# Processing rdl_dumbbell-10kg_2_102...
# Processing rdl_dumbbell_2.5kg_2_102...
# Processing rdl_dumbbell_2.5kg_7_114...
# Processing rdl_dumbbell_7.5kg_5_102...
# Processing rdl_dumbbell_7.5kg_9_18...
# Processing rdl_dumbbell_2.5kg_8_102...
# Processing rdl_dumbbell_7.5kg_4_114...
# Processing rdl_dumbbell_1kg_3_18...
# Processing rdl_dumbbell_1kg_2_102...
# Pose keypoint extraction complete! CSVs saved in /content/pose_csv_dataset

# %%
import os
import pandas as pd

data = []

CSV_DIR = '/content/pose_csv_dataset'  # Directory containing the CSV files

# Loop through each label (class) directory in the CSV directory
for label in os.listdir(CSV_DIR):
    class_dir = os.path.join(CSV_DIR, label) # Path to the class directory
    if os.path.isdir(class_dir):          # Check if it's a directory
        # Loop through each file in the class directory
        for file in os.listdir(class_dir):
            if file.endswith('.csv'):    # Check if the file is a CSV file
                csv_path = os.path.join(class_dir, file) # Full path to the CSV file
                df = pd.read_csv(csv_path)            # Read the CSV file into a Pandas DataFrame
                df['label'] = label                 # Add a 'label' column with the class name
                df['video'] = file                   # Add a 'video' column with the filename
                data.append(df)                    # Append the DataFrame to the data list

# Concatenate all into a single DataFrame
full_df = pd.concat(data, ignore_index=True) # Concatenate all DataFrames in the list
print("Combined shape:", full_df.shape)       # Print the shape (rows, columns) of the combined DataFrame
# Out:
# Combined shape: (14138, 135)

# %%
full_df.head()  # View of the first 5 rows of the dataset
# Out:
#              frame        x0        y0        z0        v0        x1  \
# 0  frame_00009.jpg  0.551812  0.574754 -0.038027  0.998848  0.545737
# 1  frame_00000.jpg  0.432927  0.466810 -0.205097  0.983814  0.437848
# 2  frame_00001.jpg  0.400312  0.493836 -0.132653  0.956673  0.404501
# 3  frame_00002.jpg  0.392901  0.511545 -0.131369  0.996530  0.395103
# 4  frame_00003.jpg  0.426719  0.472809 -0.170183  0.989553  0.431108
#
#          y1        z1        v1        x2  ...       x31       y31       z31  \
# 0  0.564036 -0.038498  0.998614  0.549707  ...  0.906977  0.586598  0.061681
# 1  0.455041 -0.219827  0.984246  0.438948  ...  0.419005  0.919513  0.210107
# 2  0.481483 -0.148790  0.962436  0.405526  ...  0.417578  0.923985  0.180020
# 3  0.500852 -0.147117  0.997596  0.395558  ...  0.413057  0.920415  0.102007
# 4  0.462486 -0.183992  0.989612  0.432652  ...  0.417033  0.916374  0.181423
#
#         v31       x32       y32       z32       v32              label  \
# 0  0.340017  0.897279  0.616264  0.172381  0.171422  Kettlebell_swings
# 1  0.935987  0.438670  0.872235  0.398581  0.741659  Kettlebell_swings
# 2  0.843390  0.440120  0.836672  0.431205  0.497793  Kettlebell_swings
# 3  0.973134  0.405331  0.754452  0.482915  0.577804  Kettlebell_swings
# 4  0.826518  0.419367  0.900731  0.326420  0.517659  Kettlebell_swings
#
#                              video
# 0  kettlebell_swings_8kg_2_102.csv
# 1  kettlebell_swings_6kg_4_114.csv
# 2  kettlebell_swings_6kg_4_114.csv
# 3  kettlebell_swings_6kg_4_114.csv
# 4  kettlebell_swings_6kg_4_114.csv
#
# [5 rows x 135 columns]

# %%
full_df.to_csv('full_pose_dataset.csv', index=False) # Save the combined DataFrame to a CSV file
